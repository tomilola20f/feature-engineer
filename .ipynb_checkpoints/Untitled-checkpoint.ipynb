# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil
#
# 19/01/2023  13:03    <DIR>          .
# 22/07/2022  00:01    <DIR>          ..
# 19/11/2022  08:41             3,551 .bash_history
# 31/07/2022  18:15                55 .gitconfig
# 13/11/2022  15:45    <DIR>          .ipynb_checkpoints
# 30/07/2022  11:27    <DIR>          .ipython
# 30/07/2022  14:12    <DIR>          .jupyter
# 08/08/2022  21:10    <DIR>          .matplotlib
# 06/06/2022  16:28    <DIR>          .vscode
# 02/05/2021  00:34    <DIR>          3D Objects
# 22/07/2022  00:07    <DIR>          Contacts
# 31/10/2022  11:52    <DIR>          Credit-Prediction-to-Default
# 26/07/2022  20:54    <DIR>          data_1.01_activities
# 31/10/2022  12:04    <DIR>          data_mid_bootcamp_project_FIFA_MoneyBall-miniproject
# 02/08/2022  10:28    <DIR>          Documents
# 19/01/2023  13:23    <DIR>          Downloads
# 22/07/2022  00:07    <DIR>          Favorites
# ...

# %%
cd lab-revisiting-machine-learning
# Out:
# C:\Users\tomil\lab-revisiting-machine-learning

# %%
df = pd.read_csv("learningSet.csv")
# Out:
# C:\Users\tomil\AppData\Local\Temp\ipykernel_18740\3745723400.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("learningSet.csv")

# %%
df
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# ...

# %%
df_cat =df.select_dtypes(object)

# %%
df_cat
# Out:
#       OSOURCE STATE    ZIP MAILCODE PVASTATE NOEXCH RECINHSE RECP3 RECPGVG  \
# 0         GRI    IL  61081                        0
# 1         BOA    CA  91326                        0
# 2         AMH    NC  27017                        0
# 3         BRY    CA  95953                        0
# 4                FL  33176                        0        X     X
# ...       ...   ...    ...      ...      ...    ...      ...   ...     ...
# 95407     ASE    AK  99504                        0
# 95408     DCD    TX  77379                        0
# 95409     MBC    MI  48910                        0              X
# 95410     PRV    CA  91320                        0        X
# 95411     MCC    NC  28409                        0        X             X
#
#       RECSWEEP  ... RFA_21 RFA_22 RFA_23 RFA_24 RFA_2R RFA_2A MDMAUD_R  \
# 0               ...    S4E    S4E    S4E    S4E      L      E        X
# 1               ...    N1E    N1E           F1E      L      G        X
# ...

# %%
## Checking  for null values in all the columns

# %%
df_cat.isna().sum()
# Out:
# OSOURCE       0
# STATE         0
# ZIP           0
# MAILCODE      0
# PVASTATE      0
#            ...
# RFA_2A        0
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# GEOCODE2    132
# Length: 74, dtype: int64

# %% [markdown]
# ## Exclude the following variables by looking at the definitions. Create a new empty list called drop_list. We will append this list and then drop all the columns in this list later:

# %%
drop_list = df_cat.loc[:, ['OSOURCE', 'ZIP']]
drop_list
# Out:
#       OSOURCE    ZIP
# 0         GRI  61081
# 1         BOA  91326
# 2         AMH  27017
# 3         BRY  95953
# 4              33176
# ...       ...    ...
# 95407     ASE  99504
# 95408     DCD  77379
# 95409     MBC  48910
# 95410     PRV  91320
# 95411     MCC  28409
#
# [95412 rows x 2 columns]

# %% [markdown]
# ## Identify columns that over 85% missing values

# %%
df_missingvalues = df.isnull().sum()/df.shape[0]*100
drop_missingvalues = df_missingvalues[df_missingvalues>85].keys()

# %%
drop_missingvalues
# Out:
# Index(['NUMCHLD', 'RDATE_3', 'RDATE_4', 'RDATE_5', 'RDATE_6', 'RDATE_7',
#        'RDATE_10', 'RDATE_13', 'RDATE_15', 'RDATE_17', 'RDATE_20', 'RDATE_21',
#        'RDATE_23', 'RAMNT_3', 'RAMNT_4', 'RAMNT_5', 'RAMNT_6', 'RAMNT_7',
#        'RAMNT_10', 'RAMNT_13', 'RAMNT_15', 'RAMNT_17', 'RAMNT_20', 'RAMNT_21',
#        'RAMNT_23'],
#       dtype='object')

# %%
droplist= drop_missingvalues

# %%
droplist
# Out:
# Index(['NUMCHLD', 'RDATE_3', 'RDATE_4', 'RDATE_5', 'RDATE_6', 'RDATE_7',
#        'RDATE_10', 'RDATE_13', 'RDATE_15', 'RDATE_17', 'RDATE_20', 'RDATE_21',
#        'RDATE_23', 'RAMNT_3', 'RAMNT_4', 'RAMNT_5', 'RAMNT_6', 'RAMNT_7',
#        'RAMNT_10', 'RAMNT_13', 'RAMNT_15', 'RAMNT_17', 'RAMNT_20', 'RAMNT_21',
#        'RAMNT_23'],
#       dtype='object')

# %% [markdown]
# ## Remove those columns from the dataframe

# %%
df.drop(droplist, axis=1, inplace=True)

# %% [markdown]
# ## Reduce the number of categories in the column GENDER. The column should only have either "M" for males, "F" for females, and "other" for all the rest

# %%
print(df_cat['GENDER'].value_counts())

df_cat['GENDER'] = df_cat['GENDER'].fillna('F')
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
df_cat["GENDER"] = df_cat["GENDER"].apply(lambda x : x if (x in ["F", "M"]) else "other")

# %%
df_cat["GENDER"].value_counts()
# Out:
# F        51277
# M        39094
# other     5041
# Name: GENDER, dtype: int64
